# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
import time

Names = []
Reviews = []
Dates = []
Cities = []




url = """https://www.flipkart.com/apple-iphone-15-blue-128-gb/product-reviews/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYQRLPCQ&marketplace=FLIPKART"""
driver = webdriver.Chrome()
driver.get(url)

for i in range(2,5):    
    
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    
    Names = soup.find_all("p",{"class":"_2NsDsF AwS1CA"})
    for i in Names:
        names.append(i.text)
    
    Cities = soup.find_all("p",{"class":"MztJPv"})
    
    for i in Cities:
        cities.append(i.text)
    
    
    Dates = soup.find_all("p",{"class":"_2NsDsF"})
    
    for i in Dates:
        dates.append(i.text)
    
    for i in dates:
        act_dates = dates[1::2]
    
    
    Reviews = soup.find_all("div", {"class":"ZmyHeo"})
    
    for i in Reviews:
        reviews.append(i.text)
    
    
    time.sleep(3)
    
    driver.find_element(By.XPATH, """/html/body/div[1]/div/div[3]/div/div/div[2]/div[13]/div/div/nav/a[11]""").click()

# %%
url = """https://www.flipkart.com/apple-iphone-15-blue-128-gb/product-reviews/itmbf14ef54f645d?pid=MOBGTAGPAQNVFZZY&lid=LSTMOBGTAGPAQNVFZZYQRLPCQ&marketplace=FLIPKART&page=16"""
driver = webdriver.Chrome()
driver.get(url)
for i in range(2,5):    
    
    time.sleep(2)
    soup = BeautifulSoup(driver.page_source, "html.parser")
    
    Names = soup.find_all("p",{"class":"_2NsDsF AwS1CA"})
    for i in Names:
        names.append(i.text)
    
    Cities = soup.find_all("p",{"class":"MztJPv"})
    
    for i in Cities:
        cities.append(i.text)
    
    
    Dates = soup.find_all("p",{"class":"_2NsDsF"})
    
    for i in Dates:
        dates.append(i.text)
    
    for i in dates:
        act_dates = dates[1::2]
    
    
    Reviews = soup.find_all("div", {"class":"ZmyHeo"})
    
    for i in Reviews:
        reviews.append(i.text)
    
    
    time.sleep(3)
    
    driver.find_element(By.XPATH, """/html/body/div/div/div[3]/div/div/div[2]/div[6]/div/div/nav/a[12]""").click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[49], line 36
#      31     reviews.append(i.text)
#      34 time.sleep(3)
# ---> 36 driver.find_element(By.XPATH, """/html/body/div/div/div[3]/div/div/div[2]/div[6]/div/div/nav/a[12]""").click()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:766, in WebDriver.find_element(self, by, value)
#     763         raise NoSuchElementException(f"Cannot locate relative element with: {by.root}")
#     764     return elements[0]
# --> 766 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:380, in WebDriver.execute(self, driver_command, params)
#     378 response = self.command_executor.execute(driver_command, params)
#     379 if response:
# --> 380     self.error_handler.check_response(response)
#     381     response["value"] = self._unwrap_value(response.get("value", None))
#     382     return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div/div/div[3]/div/div/div[2]/div[6]/div/div/nav/a[12]"}
#   (Session info: chrome=131.0.6778.70); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF6A4462775+28773]
# 	(No symbol) [0x00007FF6A43CAFB0]
# 	(No symbol) [0x00007FF6A426552A]
# 	(No symbol) [0x00007FF6A42B8EAE]
# 	(No symbol) [0x00007FF6A42B919C]
# 	(No symbol) [0x00007FF6A43023F7]
# 	(No symbol) [0x00007FF6A42DEFDF]
# 	(No symbol) [0x00007FF6A42FF1A4]
# 	(No symbol) [0x00007FF6A42DED43]
# 	(No symbol) [0x00007FF6A42AA548]
# 	(No symbol) [0x00007FF6A42AB6B1]
# 	GetHandleVerifier [0x00007FF6A478F45D+3358029]
# 	GetHandleVerifier [0x00007FF6A47A430D+3443709]
# 	GetHandleVerifier [0x00007FF6A47983FD+3394797]
# 	GetHandleVerifier [0x00007FF6A452929B+842635]
# 	(No symbol) [0x00007FF6A43D654F]
# 	(No symbol) [0x00007FF6A43D1FA4]
# 	(No symbol) [0x00007FF6A43D213D]
# 	(No symbol) [0x00007FF6A43C1629]
# 	BaseThreadInitThunk [0x00007FF8B014259D+29]
# 	RtlUserThreadStart [0x00007FF8B246AF38+40]

# %%
import pandas as pd
df = pd.DataFrame({"Names":names, "Citites":cities,"Dates":act_dates, "Reviews":reviews})
df
# Out:
#                  Names                          Citites          Dates  \
# 0     Mousam  Guha Roy      Certified Buyer, Matialihat      Oct, 2023
# 1        mohit  yadav           Certified Buyer, Mumbai  11 months ago
# 2               Ajin V        Certified Buyer, Balaghat      Oct, 2023
# 3      Prithivi Boruah         Certified Buyer, Bokajan      Oct, 2023
# 4       bijaya mohanty       Certified Buyer, Baleshwar   5 months ago
# ..                 ...                              ...            ...
# 328  CHETAN  TILWALIA             Certified Buyer, Loni   7 months ago
# 329       Manish Gupta            Certified Buyer, Isri   7 months ago
# 330    santosh  parida       Certified Buyer, Hyderabad   8 months ago
# 331     Inderjit Singh  Certified Buyer, Thane District   8 months ago
# 332    VENKATESH REDDY       Certified Buyer, Bengaluru   9 months ago
#
#                                                Reviews
# 0                                   Very niceREAD MORE
# 1                                     Nice ❤️READ MORE
# 2                        High quality camera😍READ MORE
# 3        Camera Quality Is Improved Loving ItREAD MORE
# 4    Just go for it.Amazing one.Beautiful camera wi...
# ..                                                 ...
# 328                                    Nice 👌READ MORE
# 329                             Heating issueREAD MORE
# 330                              Excellent!!!READ MORE
# 331  Very good deal and fastest delivery in next da...
# 332                        Super Good ProductREAD MORE
#
# [333 rows x 4 columns]

# %%
df["Reviews"] = df["Reviews"].str.lower()
df
# Out:
#                  Names                          Citites          Dates  \
# 0     Mousam  Guha Roy      Certified Buyer, Matialihat      Oct, 2023
# 1        mohit  yadav           Certified Buyer, Mumbai  11 months ago
# 2               Ajin V        Certified Buyer, Balaghat      Oct, 2023
# 3      Prithivi Boruah         Certified Buyer, Bokajan      Oct, 2023
# 4       bijaya mohanty       Certified Buyer, Baleshwar   5 months ago
# ..                 ...                              ...            ...
# 328  CHETAN  TILWALIA             Certified Buyer, Loni   7 months ago
# 329       Manish Gupta            Certified Buyer, Isri   7 months ago
# 330    santosh  parida       Certified Buyer, Hyderabad   8 months ago
# 331     Inderjit Singh  Certified Buyer, Thane District   8 months ago
# 332    VENKATESH REDDY       Certified Buyer, Bengaluru   9 months ago
#
#                                                Reviews
# 0                                   very niceread more
# 1                                     nice ❤️read more
# 2                        high quality camera😍read more
# 3        camera quality is improved loving itread more
# 4    just go for it.amazing one.beautiful camera wi...
# ..                                                 ...
# 328                                    nice 👌read more
# 329                             heating issueread more
# 330                              excellent!!!read more
# 331  very good deal and fastest delivery in next da...
# 332                        super good productread more
#
# [333 rows x 4 columns]

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
from nltk.tokenize import word_tokenize
from textblob import TextBlob
import string

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')

df["Reviews_t"] = df['Reviews'].apply(sent_tokenize)
df
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ayush\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#                  Names                          Citites          Dates  \
# 0     Mousam  Guha Roy      Certified Buyer, Matialihat      Oct, 2023
# 1        mohit  yadav           Certified Buyer, Mumbai  11 months ago
# 2               Ajin V        Certified Buyer, Balaghat      Oct, 2023
# 3      Prithivi Boruah         Certified Buyer, Bokajan      Oct, 2023
# 4       bijaya mohanty       Certified Buyer, Baleshwar   5 months ago
# ..                 ...                              ...            ...
# 328  CHETAN  TILWALIA             Certified Buyer, Loni   7 months ago
# 329       Manish Gupta            Certified Buyer, Isri   7 months ago
# 330    santosh  parida       Certified Buyer, Hyderabad   8 months ago
# 331     Inderjit Singh  Certified Buyer, Thane District   8 months ago
# 332    VENKATESH REDDY       Certified Buyer, Bengaluru   9 months ago
#
#                                                Reviews  \
# 0                                   very niceread more
# 1                                     nice ❤️read more
# 2                        high quality camera😍read more
# 3        camera quality is improved loving itread more
# 4    just go for it.amazing one.beautiful camera wi...
# ..                                                 ...
# 328                                    nice 👌read more
# 329                             heating issueread more
# 330                              excellent!!!read more
# 331  very good deal and fastest delivery in next da...
# 332                        super good productread more
#
#                                              Reviews_t
# 0                                 [very niceread more]
# 1                                   [nice ❤️read more]
# 2                      [high quality camera😍read more]
# 3      [camera quality is improved loving itread more]
# 4    [just go for it.amazing one.beautiful camera w...
# ..                                                 ...
# 328                                  [nice 👌read more]
# 329                           [heating issueread more]
# 330                          [excellent!!, !read more]
# 331  [very good deal and fastest delivery in next d...
# 332                      [super good productread more]
#
# [333 rows x 5 columns]

# %%
from statistics import mean

def get_polarity(sentences):
    return [TextBlob(sentence).sentiment.polarity for sentence in sentences]

df['Polarity'] = df['Reviews_t'].apply(get_polarity)

def calculate_average_polarity(polarities):
    return mean(polarities) if polarities else 0

df['Average_Polarity'] = df['Polarity'].apply(calculate_average_polarity)

df.head(10)
# Out:
#                    Names                           Citites          Dates  \
# 0       Mousam  Guha Roy       Certified Buyer, Matialihat      Oct, 2023
# 1          mohit  yadav            Certified Buyer, Mumbai  11 months ago
# 2                 Ajin V         Certified Buyer, Balaghat      Oct, 2023
# 3        Prithivi Boruah          Certified Buyer, Bokajan      Oct, 2023
# 4         bijaya mohanty        Certified Buyer, Baleshwar   5 months ago
# 5      Flipkart Customer           Certified Buyer, Aizawl   9 months ago
# 6  Sheetla Prasad Maurya        Certified Buyer, Sultanpur      Oct, 2023
# 7     Arunji Govindaraju          Certified Buyer, Chennai   9 months ago
# 8           Nikhil Kumar  Certified Buyer, Meerut Division   9 months ago
# 9              Raj Singh          Certified Buyer, Kolkata  11 months ago
#
#                                              Reviews  \
# 0                                 very niceread more
# 1                                   nice ❤️read more
# 2                      high quality camera😍read more
# 3      camera quality is improved loving itread more
# 4  just go for it.amazing one.beautiful camera wi...
# 5  awesome photography experience. battery backup...
# 6  best mobile phonecamera quality is very nice b...
# 7  awesome product very happy to hold this. bette...
# 8  switch from oneplus to iphone i am stunned wit...
# 9                  for me its 10 out of 10✨read more
#
#                                            Reviews_t  \
# 0                               [very niceread more]
# 1                                 [nice ❤️read more]
# 2                    [high quality camera😍read more]
# 3    [camera quality is improved loving itread more]
# 4  [just go for it.amazing one.beautiful camera w...
# 5  [awesome photography experience., battery back...
# 6  [best mobile phonecamera quality is very nice ...
# 7  [awesome product very happy to hold this., bet...
# 8  [switch from oneplus to iphone i am stunned wi...
# 9                [for me its 10 out of 10✨read more]
#
#                           Polarity  Average_Polarity
# 0                           [0.35]          0.350000
# 1                           [0.55]          0.550000
# 2                           [0.33]          0.330000
# 3                           [0.55]          0.550000
# 4             [0.3444444444444444]          0.344444
# 5                  [1.0, 0.7, 0.5]          0.733333
# 6                          [0.718]          0.718000
# 7  [1.0, 0.5, 0.46190476190476193]          0.653968
# 8                      [0.0, 0.75]          0.375000
# 9                            [0.5]          0.500000

# %%
df["Average_Polarity"].mean()
# Out:
# 0.4915204609371276

# %%
ext negative, negative, neutral, positive, extremely positive
